# %%
import pandas as pd

# %%
orders = pd.read_csv("olist_orders_dataset.csv")
customers = pd.read_csv("olist_customers_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
payments = pd.read_csv("olist_order_payments_dataset.csv")
reviews = pd.read_csv("olist_order_reviews_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
geolocation = pd.read_csv("olist_geolocation_dataset.csv")
category_translation = pd.read_csv("product_category_name_translation.csv")

# %%
def summarize(df, name):
    print("="*70)
    print(f"{name.upper()}")
    print("="*70)

    print(f"Shape : {df.shape}")

    print("\nData Types")
    print(df.dtypes)

    print("\nMissing Values")
    print(df.isnull().sum())

    print("\nDuplicate Rows")
    print(df.duplicated().sum())

    print("\nFirst 5 Rows")
    display(df.head())

# %%
summarize(customers, "customers")

summarize(orders, "orders")

summarize(order_items, "order Items")

summarize(payments, "payments")

summarize(reviews, "reviews")

summarize(products, "products")

summarize(sellers, "sellers")

summarize(geolocation, "geolocation")

summarize(category_translation, "Category Translation")
# Out:
# ...
# CUSTOMERS
# ...
# Shape : (99441, 5)
#
# Data Types
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object
#
# Missing Values
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Duplicate Rows
# 0
#
# First 5 Rows
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# *DATA CLEANING*

# %%
date_cols = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in date_cols:
    orders[col] = pd.to_datetime(orders[col])

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  datetime64[us]
#  4   order_approved_at              99281 non-null  datetime64[us]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[us]
#  6   order_delivered_customer_date  96476 non-null  datetime64[us]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[us]
# dtypes: datetime64[us](5), str(3)
# memory usage: 6.1 MB

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# NO DUPLICATE RECORDS FOUND

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders[orders["order_approved_at"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# canceled     141
# delivered     14
# created        5
# Name: count, dtype: int64

# %%
orders[orders["order_delivered_carrier_date"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# unavailable    609
# canceled       550
# invoiced       314
# processing     301
# created          5
# approved         2
# delivered        2
# Name: count, dtype: int64

# %%
orders[orders["order_delivered_customer_date"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         8
# created           5
# approved          2
# Name: count, dtype: int64

# %% [markdown]
# Conclusion
#
# • No duplicate records found.
#
# • Datetime columns successfully converted.
#
# • Missing values in approval and delivery timestamps are primarily associated with canceled and created orders, which is consistent with the business process.
#
# • These missing values will be retained.

# %% [markdown]
# Next Dataset: Customers
# (No missing values)
#
# Next Dataset : Products

# %%
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products[products.isnull().any(axis=1)]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
missing_products = pd.DataFrame({
    "Missing Values": products.isnull().sum(),
    "Percentage": round(products.isnull().mean() * 100, 2)
})

missing_products[missing_products["Missing Values"] > 0]
# Out:
#                             Missing Values  Percentage
# product_category_name                  610        1.85
# product_name_lenght                    610        1.85
# product_description_lenght             610        1.85
# product_photos_qty                     610        1.85
# product_weight_g                         2        0.01
# product_length_cm                        2        0.01
# product_height_cm                        2        0.01
# product_width_cm                         2        0.01

# %%
products["product_category_name"] = products["product_category_name"].fillna("Unknown")

# %%
products = products.dropna(
    subset=[
        "product_weight_g",
        "product_length_cm",
        "product_height_cm",
        "product_width_cm"
    ]
)

# %%
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name           0
# product_name_lenght           609
# product_description_lenght    609
# product_photos_qty            609
# product_weight_g                0
# product_length_cm               0
# product_height_cm               0
# product_width_cm                0
# dtype: int64

# %% [markdown]
# ## Products Dataset Cleaning
#
# ### Observations
# - No duplicate records found.
# - Product category had missing values and was labeled as "Unknown".
# - Two records had missing product dimensions and were removed due to their negligible impact on the dataset.

# %%
order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Order Items Dataset
#
# - No missing values found.
# - No duplicate records found.
# - Dataset is ready for analysis.

# %%
payments.isnull().sum()
payments.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Order Items Dataset
#
# - No missing values found.
# - No duplicate records found.
# - Dataset is ready for analysis.

# %%
payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# ### Payments Dataset
#
# - No missing values found.
# - No duplicate records found.
# - Payment methods were inspected for consistency.

# %%
reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Reviews Dataset
#
# - Missing review comments are expected because customers may submit only ratings.
# - No imputation performed.

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
category_translation.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
orders.to_csv("clean_orders.csv", index=False)

customers.to_csv("clean_customers.csv", index=False)

products.to_csv("clean_products.csv", index=False)

order_items.to_csv("clean_order_items.csv", index=False)

payments.to_csv("clean_payments.csv", index=False)

reviews.to_csv("clean_reviews.csv", index=False)

sellers.to_csv("clean_sellers.csv", index=False)
